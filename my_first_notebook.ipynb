# %% [markdown]
# The relationship between the hardware and software is like the relationship between human body and the thoughts that drive it.
#
#
# *   **Hardware**:
#     The hardware is the pyhsical structure which you can touch,feel.These are the pyhsical components which are used to do some tasks with some instructions or set of actions.
#     **Examples: CPU, Mouse, Keyboard,etc,.
#
# *   **Software**:
#     The software is the data/ instructions stored with the body.It is the brain of a computer. You cant touch or feel them. For example human thoughts you cannot touch but it is what tells our body to do certain actions or to move. similarly the software gives certain instructions to do a task to the CPU or GPU.
#     **Examples:** windows, linux, chrome, excel, etc,.
