# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Welcome Akanksha")
# Out:
# Welcome Akanksha

# %%
print("a+b:",1+2)
# Out:
# a+b: 3

# %%
num = int(input("enter a number"))
if num % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# enter a number78213434
# even
